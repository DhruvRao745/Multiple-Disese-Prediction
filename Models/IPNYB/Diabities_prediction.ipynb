# %% [markdown]
# ***Importing The Dependencies***

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# ***Data Collection and Analysis***

# %%
# Loading the Datasets to a pandas DataFrame
diabetes_dataset = pd.read_csv("C:/Users/HP/OneDrive/Desktop/MDP/Data/Diabetes Prediction/diabetes.csv")

# %%
# Printing the first 5 rows of the dataset
diabetes_dataset.head()
# Out:
#    Age  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0   50            6      148             72             35        0  33.6
# 1   31            1       85             66             29        0  26.6
# 2   32            8      183             64              0        0  23.3
# 3   21            1       89             66             23       94  28.1
# 4   33            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Outcome
# 0                     0.627        1
# 1                     0.351        0
# 2                     0.672        1
# 3                     0.167        0
# 4                     2.288        1

# %%
# Number of the Rows and Columns
diabetes_dataset.shape
# Out:
# (768, 9)

# %%
# Getting the statstical measures off the data
diabetes_dataset.describe()
# Out:
#               Age  Pregnancies     Glucose  BloodPressure  SkinThickness  \
# count  768.000000   768.000000  768.000000     768.000000     768.000000
# mean    33.240885     3.845052  120.894531      69.105469      20.536458
# std     11.760232     3.369578   31.972618      19.355807      15.952218
# min     21.000000     0.000000    0.000000       0.000000       0.000000
# 25%     24.000000     1.000000   99.000000      62.000000       0.000000
# 50%     29.000000     3.000000  117.000000      72.000000      23.000000
# 75%     41.000000     6.000000  140.250000      80.000000      32.000000
# max     81.000000    17.000000  199.000000     122.000000      99.000000
#
#           Insulin         BMI  DiabetesPedigreeFunction     Outcome
# count  768.000000  768.000000                768.000000  768.000000
# mean    79.799479   31.992578                  0.471876    0.348958
# std    115.244002    7.884160                  0.331329    0.476951
# ...

# %%
diabetes_dataset['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
diabetes_dataset.groupby('Outcome').mean()
# Out:
#                Age  Pregnancies     Glucose  BloodPressure  SkinThickness  \
# Outcome
# 0        31.190000     3.298000  109.980000      68.184000      19.664000
# 1        37.067164     4.865672  141.257463      70.824627      22.164179
#
#             Insulin        BMI  DiabetesPedigreeFunction
# Outcome
# 0         68.792000  30.304200                  0.429734
# 1        100.335821  35.142537                  0.550500

# %%
# Seperating the data and labels
x = diabetes_dataset.drop(columns = 'Outcome', axis=1)
y = diabetes_dataset['Outcome']

# %%
# Print the values
print(x)
# Out:
#      Age  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0     50            6      148             72             35        0  33.6
# 1     31            1       85             66             29        0  26.6
# 2     32            8      183             64              0        0  23.3
# 3     21            1       89             66             23       94  28.1
# 4     33            0      137             40             35      168  43.1
# ..   ...          ...      ...            ...            ...      ...   ...
# 763   63           10      101             76             48      180  32.9
# 764   27            2      122             70             27        0  36.8
# 765   30            5      121             72             23      112  26.2
# 766   47            1      126             60              0        0  30.1
# 767   23            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction
# ...

# %%
print(y)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# ***Data Standardization***

# %%
scaler = StandardScaler()

# %%
scaler.fit(x)
# Out:
# StandardScaler()

# %%
standardized_data = scaler.transform(x)

# %%
print(standardized_data)
# Out:
# [[ 1.4259954   0.63994726  0.84832379 ... -0.69289057  0.20401277
#    0.46849198]
#  [-0.19067191 -0.84488505 -1.12339636 ... -0.69289057 -0.68442195
#   -0.36506078]
#  [-0.10558415  1.23388019  1.94372388 ... -0.69289057 -1.10325546
#    0.60439732]
#  ...
#  [-0.27575966  0.3429808   0.00330087 ...  0.27959377 -0.73518964
#   -0.68519336]
#  [ 1.17073215 -0.84488505  0.1597866  ... -0.69289057 -0.24020459
#   -0.37110101]
#  [-0.87137393 -0.84488505 -0.8730192  ... -0.69289057 -0.20212881
#   -0.47378505]]

# %%
x = standardized_data
y = diabetes_dataset['Outcome']

# %%
print(x)
print(y)
# Out:
# [[ 1.4259954   0.63994726  0.84832379 ... -0.69289057  0.20401277
#    0.46849198]
#  [-0.19067191 -0.84488505 -1.12339636 ... -0.69289057 -0.68442195
#   -0.36506078]
#  [-0.10558415  1.23388019  1.94372388 ... -0.69289057 -1.10325546
#    0.60439732]
#  ...
#  [-0.27575966  0.3429808   0.00330087 ...  0.27959377 -0.73518964
#   -0.68519336]
#  [ 1.17073215 -0.84488505  0.1597866  ... -0.69289057 -0.24020459
#   -0.37110101]
#  [-0.87137393 -0.84488505 -0.8730192  ... -0.69289057 -0.20212881
#   -0.47378505]]
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, stratify=y, random_state=2)

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %% [markdown]
# ***Training Model***

# %%
classifier = svm.SVC(kernel='linear')

# %%
# Training the support Vector Machine Classifier
classifier.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# ***Model Evaluation***

# %% [markdown]
# ***Accuracy score***

# %%
# accuracy score on the training data
x_train_prediction = classifier.predict(x_train)
training_data_accuracy = accuracy_score(x_train_prediction, y_train)

# %%
print('Accuracy score of the training data : ',training_data_accuracy)
# Out:
# Accuracy score of the training data :  0.7866449511400652

# %%
# accuracy score on the test data
x_test_prediction = classifier.predict(x_test)
test_data_accuracy = accuracy_score(x_test_prediction, y_test)

# %%
print('Accuracy score of the test data : ', test_data_accuracy)
# Out:
# Accuracy score of the test data :  0.7727272727272727

# %% [markdown]
# ***Making a Predictive System***

# %% [markdown]
# #END OF THE PROJECT

# %%
input_data = (50,6,148,72,35,0,33.6,0.627)

# changing the input data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

# standardize the input data
std_data = scaler.transform(input_data_reshaped)
print(std_data)

prediction = classifier.predict(std_data)
print(prediction)

if (prediction[0] == 0):
  print('The person is not diabetic')
else:
  print('The person is diabetic')
# Out:
# [[ 1.4259954   0.63994726  0.84832379  0.14964075  0.90726993 -0.69289057
#    0.20401277  0.46849198]]
# [1]
# The person is diabetic
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import joblib
model = 'diabetes_model'

# %%
joblib.dump(model, 'diabetes_model.pkl')
# Out:
# ['diabetes_model.pkl']
